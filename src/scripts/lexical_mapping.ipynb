# %%
import pandas as pd
import sys
import os
# !pip install curies
# !pip install sssom -U
import curies
from sssom.parsers import from_sssom_dataframe
from sssom.context import get_default_metadata
from sssom.writers import write_table
# Out:
# Requirement already satisfied: curies in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (0.3.0)
# Requirement already satisfied: pytrie in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from curies) (0.4.0)
# Requirement already satisfied: requests in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from curies) (2.28.1)
# Requirement already satisfied: sortedcontainers in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pytrie->curies) (2.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->curies) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->curies) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->curies) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->curies) (1.26.10)
# Requirement already satisfied: sssom in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (0.3.16)
# Requirement already satisfied: pandas in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (1.4.3)
# Requirement already satisfied: numpy in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (1.23.1)
# Requirement already satisfied: pyyaml in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (6.0)
# Requirement already satisfied: setuptools in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (63.2.0)
# Requirement already satisfied: click in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (8.1.3)
# Requirement already satisfied: sparqlwrapper in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (2.0.0)
# Requirement already satisfied: validators>=0.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (0.20.0)
# Requirement already satisfied: networkx in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (2.8.4)
# Requirement already satisfied: rdflib>=6 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (6.1.1)
# Requirement already satisfied: deprecation in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (2.1.0)
# Requirement already satisfied: linkml in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (1.3.2)
# Requirement already satisfied: sssom-schema in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (0.9.4)
# Requirement already satisfied: pandasql in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (0.7.3)
# Requirement already satisfied: bioregistry in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (0.5.40)
# Requirement already satisfied: pyparsing==2.4.7 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (2.4.7)
# Requirement already satisfied: scipy in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sssom) (1.8.1)
# Requirement already satisfied: isodate in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from rdflib>=6->sssom) (0.6.1)
# Requirement already satisfied: decorator>=3.4.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from validators>=0.0->sssom) (5.1.1)
# Requirement already satisfied: requests in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from bioregistry->sssom) (2.28.1)
# Requirement already satisfied: tqdm in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from bioregistry->sssom) (4.64.0)
# Requirement already satisfied: more-click in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from bioregistry->sssom) (0.1.1)
# Requirement already satisfied: pystow>=0.1.13 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from bioregistry->sssom) (0.4.5)
# Requirement already satisfied: pydantic in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from bioregistry->sssom) (1.9.1)
# Requirement already satisfied: packaging in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from deprecation->sssom) (20.9)
# Requirement already satisfied: myst-parser in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.18.0)
# Requirement already satisfied: jinja2 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (3.1.2)
# Requirement already satisfied: graphviz>=0.10.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.20.1)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: jsonasobj2<2.0.0,>=1.0.3 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (1.0.4)
# Requirement already satisfied: sphinx-click in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (4.3.0)
# Requirement already satisfied: parse in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (1.19.0)
# Requirement already satisfied: pyjsg>=0.11.6 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.11.10)
# Requirement already satisfied: hbreader in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.9.1)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (1.4.39)
# Requirement already satisfied: linkml-runtime<2.0.0,>=1.3.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (1.3.0)
# Requirement already satisfied: pyshex>=0.7.20 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.8.1)
# Requirement already satisfied: python-dateutil in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (2.8.2)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (4.7.2)
# Requirement already satisfied: antlr4-python3-runtime<4.10,>=4.9.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (4.9.3)
# Requirement already satisfied: linkml-dataops in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.1.0)
# Requirement already satisfied: prefixcommons>=0.1.7 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.1.11)
# Requirement already satisfied: watchdog>=0.9.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (2.1.9)
# Requirement already satisfied: openpyxl in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (3.0.10)
# Requirement already satisfied: pyshexc>=0.8.3 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml->sssom) (0.9.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pandas->sssom) (2022.1)
# Requirement already satisfied: six in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from isodate->rdflib>=6->sssom) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from jsonschema>=3.0.1->linkml->sssom) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from jsonschema>=3.0.1->linkml->sssom) (21.4.0)
# Requirement already satisfied: json-flattener>=0.1.9 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml-runtime<2.0.0,>=1.3.0->linkml->sssom) (0.1.9)
# Requirement already satisfied: deprecated in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml-runtime<2.0.0,>=1.3.0->linkml->sssom) (1.2.13)
# Requirement already satisfied: jsonasobj>=1.2.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyjsg>=0.11.6->linkml->sssom) (1.3.1)
# Requirement already satisfied: rdflib-shim in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyshex>=0.7.20->linkml->sssom) (1.0.3)
# Requirement already satisfied: urllib3 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyshex>=0.7.20->linkml->sssom) (1.26.10)
# Requirement already satisfied: chardet in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyshex>=0.7.20->linkml->sssom) (5.0.0)
# Requirement already satisfied: sparqlslurper>=0.5.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyshex>=0.7.20->linkml->sssom) (0.5.1)
# Requirement already satisfied: cfgraph>=0.2.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyshex>=0.7.20->linkml->sssom) (0.2.1)
# Requirement already satisfied: shexjsg>=0.8.2 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from pyshex>=0.7.20->linkml->sssom) (0.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->bioregistry->sssom) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->bioregistry->sssom) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from requests->bioregistry->sssom) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sqlalchemy>=1.4.31->linkml->sssom) (1.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from jinja2->linkml->sssom) (2.1.1)
# Requirement already satisfied: jsonpatch in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml-dataops->linkml->sssom) (1.32)
# Requirement already satisfied: jsonpath-ng in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml-dataops->linkml->sssom) (1.5.3)
# Requirement already satisfied: ruamel.yaml in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from linkml-dataops->linkml->sssom) (0.17.21)
# Requirement already satisfied: mdit-py-plugins~=0.3.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from myst-parser->linkml->sssom) (0.3.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=1.0.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from myst-parser->linkml->sssom) (2.1.0)
# Requirement already satisfied: typing-extensions in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from myst-parser->linkml->sssom) (4.3.0)
# Requirement already satisfied: sphinx<6,>=4 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from myst-parser->linkml->sssom) (5.1.1)
# Requirement already satisfied: docutils<0.19,>=0.15 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from myst-parser->linkml->sssom) (0.18.1)
# Requirement already satisfied: et-xmlfile in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from openpyxl->linkml->sssom) (1.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=1.0.0->myst-parser->linkml->sssom) (0.1.2)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (1.0.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (0.7.12)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (1.0.3)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (1.1.5)
# Requirement already satisfied: snowballstemmer>=1.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (2.2.0)
# Requirement already satisfied: imagesize in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (1.4.1)
# Requirement already satisfied: babel>=1.3 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (2.10.3)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (1.0.2)
# Requirement already satisfied: Pygments>=2.0 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from sphinx<6,>=4->myst-parser->linkml->sssom) (2.12.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from deprecated->linkml-runtime<2.0.0,>=1.3.0->linkml->sssom) (1.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from jsonpatch->linkml-dataops->linkml->sssom) (2.3)
# Requirement already satisfied: ply in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from jsonpath-ng->linkml-dataops->linkml->sssom) (3.11)
# Requirement already satisfied: rdflib-jsonld==0.6.1 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from rdflib-shim->pyshex>=0.7.20->linkml->sssom) (0.6.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /Users/matentzn/.pyenv/versions/3.10.4/envs/sssom/lib/python3.10/site-packages (from ruamel.yaml->linkml-dataops->linkml->sssom) (0.2.6)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
profile = sys.argv[1]
profile = "all"
stopwords = ['abnormally','abnormal','aberrant','variant']
outdir = "../curation/data"
uphenorelease_dir = "../curation/upheno-release/{}/".format(profile)

## IN
upheno_mapping_logical = os.path.join(uphenorelease_dir,"upheno_mapping_logical.csv")
upheno_species_lexical_file = os.path.join(uphenorelease_dir,"upheno_species_lexical.csv")

## OUT
upheno_mapping_all = os.path.join(uphenorelease_dir,"upheno_mapping_all.csv")
upheno_mapping_lexical = os.path.join(uphenorelease_dir,"upheno_mapping_lexical.csv")
upheno_mapping_lexical_template = os.path.join(uphenorelease_dir,"upheno_mapping_lexical_template.csv")
upheno_mapping_problematic = os.path.join(uphenorelease_dir,"upheno_mapping_problematic.csv")

## Load lexical data
df = pd.read_csv(upheno_species_lexical_file)
df.columns = ['iri','p','label']

## Load logical mappings
dfl1 = pd.read_csv(upheno_mapping_logical)[['p1','p2']]
dfl1.columns = ['subject_id','object_id']
dfl2 = dfl1.copy()
dfl2.columns = ['object_id','subject_id']
dfl = pd.concat([dfl1, dfl2], ignore_index=True, sort =False)
dfl = dfl.drop_duplicates()
dfl['mapping_justification']="semapv:LogicalReasoning"

## Prepare dataframe for labels
df_label = df[df['p']=="http://www.w3.org/2000/01/rdf-schema#label"][['iri','label']]
df_label.columns = ['iri','label']

# %%
df.head()
# Out:
#                                              iri  \
# 0  http://purl.obolibrary.org/obo/UPHENO_0001001
# 1  http://purl.obolibrary.org/obo/UPHENO_0001001
# 2  http://purl.obolibrary.org/obo/UPHENO_0001003
# 3  http://purl.obolibrary.org/obo/UPHENO_0001005
# 4      http://purl.obolibrary.org/obo/MP_0001417
#
#                                             p  \
# 0  http://www.w3.org/2000/01/rdf-schema#label
# 1  http://www.w3.org/2000/01/rdf-schema#label
# 2  http://www.w3.org/2000/01/rdf-schema#label
# 3  http://www.w3.org/2000/01/rdf-schema#label
# 4  http://www.w3.org/2000/01/rdf-schema#label
#
#                                             label
# 0                                       phenotype
# 1                                       Phenotype
# 2                    phenotype by ontology source
# 3           abnormal phenotype by ontology source
# 4  decreased exploration in new environment (MPO)

# %%
dfl.head()
# Out:
#                                        subject_id  \
# 0       http://purl.obolibrary.org/obo/MP_0011461
# 1       http://purl.obolibrary.org/obo/ZP_0003906
# 2  http://purl.obolibrary.org/obo/DDPHENO_0000005
# 3      http://purl.obolibrary.org/obo/XPO_0131732
# 4       http://purl.obolibrary.org/obo/HP_0012091
#
#                                            object_id    mapping_justification
# 0          http://purl.obolibrary.org/obo/HP_0011279  semapv:LogicalReasoning
# 1          http://purl.obolibrary.org/obo/ZP_0009649  semapv:LogicalReasoning
# 2  http://purl.obolibrary.org/obo/WBPhenotype_000...  semapv:LogicalReasoning
# 3          http://purl.obolibrary.org/obo/ZP_0102753  semapv:LogicalReasoning
# 4          http://purl.obolibrary.org/obo/MP_0002693  semapv:LogicalReasoning

# %%
df_label.head()
# Out:
#                                              iri  \
# 0  http://purl.obolibrary.org/obo/UPHENO_0001001
# 1  http://purl.obolibrary.org/obo/UPHENO_0001001
# 2  http://purl.obolibrary.org/obo/UPHENO_0001003
# 3  http://purl.obolibrary.org/obo/UPHENO_0001005
# 4      http://purl.obolibrary.org/obo/MP_0001417
#
#                                             label
# 0                                       phenotype
# 1                                       Phenotype
# 2                    phenotype by ontology source
# 3           abnormal phenotype by ontology source
# 4  decreased exploration in new environment (MPO)

# %%
# Preprocess labels. The most important aspect to this the stopword removal. this is done by matching a stopword
# that means 'abnormal', removing it and then adding the actual prefix 'abnormal'. For example, "cell morphology, aberrant"
# will become 'abnormal cell morphology'. Other than that, most special characters other than space and the ' tick-mark
# Are removed

def apply_stopword(x, stopword):
    if x:
        if stopword in x:
            x = "abnormal "+x.replace(stopword, '')
    return x

def preprocess_labels(df, stopwords):
    df['label'] = df['label'].astype(str)
    df['label_pp'] = df['label'].str.replace(r"[(][A-Z]+[)]", "")
    df['label_pp'] = df['label_pp'].str.lower()
    df['label_pp'] = df['label_pp'].str.replace(r"[^0-9a-z' ]", "")

    for stopword in stopwords:
        df['label_pp'] = df['label_pp'].apply(lambda x: apply_stopword(x,stopword))

    df['label_pp'] = df['label_pp'].str.strip()
    df['label_pp'] = df['label_pp'].str.replace(r"[ ]+", " ")
    df=df[~df['iri'].astype(str).str.startswith('http://purl.obolibrary.org/obo/UPHENO_')]
    df=df[df['label_pp']!=""]
    d=df[['iri','label_pp']]
    d.columns=['iri','label']
    d=d.drop_duplicates()
    return d

d = preprocess_labels(df,stopwords)
l = df_label[~df_label['iri'].astype(str).str.startswith('http://purl.obolibrary.org/obo/UPHENO_')]
print(len(d))
# Out:
# <ipython-input-6-b8c59f51948b>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['label_pp'] = df['label'].str.replace(r"[(][A-Z]+[)]", "")
# <ipython-input-6-b8c59f51948b>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['label_pp'] = df['label_pp'].str.replace(r"[^0-9a-z' ]", "")
# <ipython-input-6-b8c59f51948b>:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['label_pp'] = df['label_pp'].str.replace(r"[ ]+", " ")
# 174040

# %%
dd=d.groupby('label')['iri'].apply(list).to_dict()

# %%
# This step is a complicated hack that tries to get rid of them of the false exact synonyms. 
# The idea is this: if there is an exact synonym between two terms within an ontology, we get rid of the link. 
# Sometimes, however, a synonym is shared between more than one term within and ontology and across: 
# These cases need to be

import re

def get_dupes(a):
    seen = {}
    dupes = []

    for x in a:
        if x not in seen:
            seen[x] = 1
        else:
            if seen[x] == 1:
                dupes.append(x)
            seen[x] += 1
    return dupes

cases = dict()
cases_internal = dict()
i = 0

exclude_synonyms = dict()

for label in dd:
    iris = dd.get(label)
    onts = [re.sub('[_][0-9]+', '', iri.replace("http://purl.obolibrary.org/obo/","")) for iri in iris]
    if len(onts)>1:
        if len(onts) != len(set(onts)):
            if len(set(onts))>1:
                cases[label] = iris
                print("-----------------------")
                print(label)
                print(iris)
                dupes = get_dupes(onts)
                for dupe in dupes:
                    for iri in iris:
                        if dupe in iri:
                            if label not in exclude_synonyms:
                                exclude_synonyms[label]=[]
                            exclude_synonyms[label].append(iri)
            else:
                cases_internal[label] = iris
                for iri in iris:
                    if label not in exclude_synonyms:
                        exclude_synonyms[label]=[]
                    exclude_synonyms[label].append(iri)


print(len(cases_internal))
print(len(cases))
print(len(dd))
# Out:
# -----------------------
# asd
# ['http://purl.obolibrary.org/obo/HP_0000729', 'http://purl.obolibrary.org/obo/HP_0001631', 'http://purl.obolibrary.org/obo/MP_0010403']
# 39
# 1
# 169326

# %%
x = d

# %%
# Remove all those IRIs that contained duplicates determined in the previous step
d=x
print(len(d))
for label in exclude_synonyms:
    for iri in exclude_synonyms[label]:
        d = d[~((d['iri']==iri) & (d['label']==label))]
print(len(d))
d = pd.merge(d,l,on=['iri','label'],how='outer')
print(len(d))
# Out:
# 174040
# 173960
# 273897

# %%
dd=d.groupby('label')['iri'].apply(list).to_dict()

# %%
def pairwise(t):
    it = iter(t)
    return zip(it,it)

def invert_dol_nonunique(d):
    newdict = {}
    for k in d:
        for v in d[k]:
            newdict.setdefault(v, []).append(k)
    return newdict

def merge_label_equivalent_cliques(dd_rv):
    merge_labels = dict()
    for iri in dd_rv:
        labels_to_merge = dd_rv.get(iri)
        if len(labels_to_merge)>1:
            for lab in labels_to_merge:
                if lab not in merge_labels:
                    merge_labels[lab] = []
                merge_labels[lab] = list(set(merge_labels[lab]+labels_to_merge))
    return merge_labels

dd_rv = invert_dol_nonunique(dd)
merge_labels = merge_label_equivalent_cliques(dd_rv)

# %%
l[l['iri']=="http://purl.obolibrary.org/obo/HP_0011138"]
# Out:
#                                              iri  \
# 30282  http://purl.obolibrary.org/obo/HP_0011138
#
#                                              label
# 30282  Abnormality of skin adnexa morphology (HPO)

# %%
converter = curies.get_obo_converter()

def compute_mappings(dd,l,meta):
    data = []
    done = set()
    for label in dd:
        if label in done:
            continue
        done.add(label)
        iris = dd.get(label)
        if label in merge_labels:
            for lab in merge_labels[label]:
                iris.extend(dd.get(lab))
                done.add(lab)
        iris = list(set(iris))
        if len(iris)>1:
            #print(iris)
            pairs = pairwise(iris)
            for pair in pairs:
                curie1 = pair[0]
                curie2 = pair[1]
                data.append([curie1, curie2])
                data.append([curie2, curie1])
    df_mappings =  pd.DataFrame.from_records(data)
    df_mappings = df_mappings.drop_duplicates()
    df_mappings['mapping_justification'] = 'semapv:LexicalMatching'
    df_mappings['predicate_id'] = 'skos:exactMatch'
    df_mappings.columns = ['subject_id','object_id','mapping_justification','predicate_id']
    df_maps = pd.merge(df_mappings,l,  how='left', left_on=['subject_id'], right_on=['iri'])
    df_maps=df_maps.drop('iri',axis=1)
    df_maps = pd.merge(df_maps, l,  how='left', left_on=['object_id'], right_on=['iri'])
    df_maps=df_maps.drop('iri',axis=1)
    df_maps['subject_source']=["obo:"+re.sub('[_][0-9]+', '', iri.replace("http://purl.obolibrary.org/obo/","")).lower() for iri in df_maps['subject_id'].values]
    df_maps['object_source']=["obo:"+re.sub('[_][0-9]+', '', iri.replace("http://purl.obolibrary.org/obo/","")).lower() for iri in df_maps['object_id'].values]
    df_maps['subject_id']=[converter.compress(iri) for iri in df_maps['subject_id'].values]
    df_maps['object_id']=[converter.compress(iri) for iri in df_maps['object_id'].values]
    df_maps.rename(columns={'label_x': 'subject_label', 'label_y': 'object_label'}, inplace=True)
    df_maps = df_maps[df_maps['subject_id'].notna()]
    df_maps = df_maps[df_maps['object_id'].notna()]
    df_maps = df_maps[df_maps['predicate_id'].notna()]
    default_metadata = get_default_metadata()
    msdf = from_sssom_dataframe(df=df_maps, meta=meta, prefix_map=default_metadata.prefix_map)
    return msdf

meta = {
            "mapping_set_id": 'http://w3id.org/sssom/commons/monarch/upheno_lexical.custom.sssom.tsv',
            "mapping_set_description": 'A manual matching pipeline maintained by the Monarch Initiative.',
            "license": 'https://creativecommons.org/publicdomain/zero/1.0/'
       }
df_mapping_msdf = compute_mappings(dd,l,meta)

df_mapping = df_mapping_msdf.df

print(len(df_mapping))


df_mapping.head()
# Out:
# 7444
#     subject_id                      subject_label     predicate_id  \
# 0  APO:0000045                      sterile (APO)  skos:exactMatch
# 1  APO:0000045                      sterile (APO)  skos:exactMatch
# 2  APO:0000080            stress resistance (APO)  skos:exactMatch
# 3  APO:0000082    osmotic stress resistance (APO)  skos:exactMatch
# 4  APO:0000083  oxidative stress resistance (APO)  skos:exactMatch
#
#       object_id                           object_label  \
# 0  FBcv:0000364                          sterile (DPO)
# 1    MP:0001924                      infertility (MPO)
# 2  FYPO:0002046            resistance to stress (FYPO)
# 3  FYPO:0000851    resistance to osmotic stress (FYPO)
# 4  FYPO:0007161  resistance to oxidative stress (FYPO)
#
#     mapping_justification subject_source object_source
# 0  semapv:LexicalMatching        obo:apo      obo:fbcv
# 1  semapv:LexicalMatching        obo:apo        obo:mp
# 2  semapv:LexicalMatching        obo:apo      obo:fypo
# 3  semapv:LexicalMatching        obo:apo      obo:fypo
# 4  semapv:LexicalMatching        obo:apo      obo:fypo

# %%
df_mapping_msdf.clean_prefix_map()
with open(upheno_mapping_lexical, "w") as file:
    write_table(df_mapping_msdf, file)

# %%
## Step to investigate why there are mappings of terms within the same ontology.. 
## Since exact synonyms and labels were used, no such mapping should exist
## We drop them

w=df_mapping[df_mapping['subject_source']==df_mapping['object_source']]
df_maps = df_mapping[df_mapping['subject_source']!=df_mapping['object_source']]
print(len(w))
w.to_csv(upheno_mapping_problematic,index=False)
#df_maps
# print(df_mapping[df_mapping['subject_id']=="http://purl.obolibrary.org/obo/ZP_0006897"])
df_mapping_template = df_mapping[['subject_id','object_id']].copy()
df_mapping_template.columns = ['Ontology ID','EquivalentClasses']

df_mapping_template.loc[-1] = ['ID', 'AI obo:UPHENO_0000002']  # adding a row
df_mapping_template.index = df_mapping_template.index + 1  # shifting index
df_mapping_template.sort_index(inplace=True) 

#df_mapping.to_csv(upheno_mapping_lexical,index=False)
df_mapping_template.to_csv(upheno_mapping_lexical_template,index=False)

# %%
# Merging the logical mappings with the lexical ones for comparison
#print(df_maps.head())
df_m = pd.merge(df_maps[['subject_id','object_id','mapping_justification']], dfl,  how='outer', on=['subject_id','object_id'])
df_m = pd.merge(df_m,l,  how='left', left_on=['subject_id'], right_on=['iri'])
df_m=df_m.drop('iri',1)
df_m = pd.merge(df_m, l,  how='left', left_on=['object_id'], right_on=['iri'])
df_m=df_m.drop('iri',1)
df_m['mapping_justification'] = df_m["mapping_justification_x"].astype(str)+"-" + df_m["mapping_justification_y"].astype(str)
df_m['mapping_justification'] = df_m['mapping_justification'].str.replace("-nan", "")
df_m['mapping_justification'] = df_m['mapping_justification'].str.replace("nan-", "")
df_m=df_m.drop('mapping_justification_x',1)
df_m=df_m.drop('mapping_justification_y',1)

#print(df_m['mapping_justification'].value_counts(normalize=True))
#print(df_m['mapping_justification'].value_counts())

df_m.to_csv(upheno_mapping_all,index=False)

df_m.rename(columns={'label_x': 'subject_label', 'label_y': 'object_label'}, inplace=True)

df_m
