# %%
"""
Created on June 25 14:24:37 2024

@author: Nicolas Matentzoglu
"""

import os
import yaml
import pandas as pd

### Configuration
yaml.warnings({'YAMLLoadWarning': False})
#upheno_config_file = sys.argv[1]
upheno_config_file = os.path.join("/Users/matentzn/ws/upheno-dev/src/curation/upheno-config.yaml")
robot_report = "../ontology/reports/upheno-base.owl-obo-report.tsv"
to_obsolete = "../ontology/tmp/to_obsolete.tsv"
obsoletes_file = "../templates/obsolete.tsv"
upheno_id_map = "../curation/upheno_id_map.txt"

df_robot_report = pd.read_csv(robot_report, sep="\t")
df_to_obsolete = pd.read_csv(to_obsolete, sep="\t")
df_upheno_id_map = pd.read_csv(upheno_id_map, sep="\t")
df_obsoletes = pd.read_csv(obsoletes_file, sep="\t")

automatic_data_dir = "../patterns/data/automatic/"

# %%
df_robot_report
# Out:
#        Level             Rule Name         Subject     Property  \
# 0      ERROR  duplicate_definition  UPHENO:0079981  IAO:0000115
# 1      ERROR  duplicate_definition  UPHENO:0085427  IAO:0000115
# 2      ERROR  duplicate_definition  UPHENO:0079982  IAO:0000115
# 3      ERROR  duplicate_definition  UPHENO:0085425  IAO:0000115
# 4      ERROR  duplicate_definition  UPHENO:0079901  IAO:0000115
# ...      ...                   ...             ...          ...
# 10610   INFO  lowercase_definition  UPHENO:0090159  IAO:0000115
# 10611   INFO  lowercase_definition  UPHENO:0090160  IAO:0000115
# 10612   INFO  lowercase_definition  UPHENO:0090161  IAO:0000115
# 10613   INFO  lowercase_definition  UPHENO:0090162  IAO:0000115
# 10614   INFO  lowercase_definition  UPHENO:0090163  IAO:0000115
#
#                                                    Value
# 0      The presence of an increased number of vestibu...
# 1      The presence of an increased number of vestibu...
# 2      The presence of an increased number of type II...
# 3      The presence of an increased number of type II...
# 4      The presence of an increased number of type II...
# ...                                                  ...
# 10610  longer, increased length of, photoreceptor out...
# 10611       longer, increased length of, dendritic spine
# 10612       longer, increased length of, sperm flagellum
# 10613             longer, increased length of, manchette
# 10614             longer, increased length of, germ tube
#
# [10615 rows x 5 columns]

# %%
df_to_obsolete
# Out:
#          obsolete     replacement
# 0  UPHENO:0080366  UPHENO:0051215

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 20)     # Show all rows
pd.set_option('display.max_colwidth', None) # Show full column width
pd.set_option('display.width', None)        # Automatically adjust the display width to the notebook

print(df_upheno_id_map[df_upheno_id_map['defined_class']=='http://purl.obolibrary.org/obo/UPHENO_0079981'])
df_upheno_id_map[df_upheno_id_map['defined_class']=='http://purl.obolibrary.org/obo/UPHENO_0085427']
# Out:
#                                        defined_class  \
# 79471  http://purl.obolibrary.org/obo/UPHENO_0079981
#
#                                                                                                id  \
# 79471  http://purl.obolibrary.org/obo/CL_0000609-abnormallyIncreasedNumberOfCellularComponent.tsv
#
#             upheno_id
# 79471  UPHENO:0079981
#                                        defined_class  \
# 84917  http://purl.obolibrary.org/obo/UPHENO_0085427
#
#                                                                                               id  \
# 84917  http://purl.obolibrary.org/obo/CL_0000609-abnormallyIncreasedNumberOfAnatomicalEntity.tsv
#
#             upheno_id
# 84917  UPHENO:0085427

# %%
import pandas as pd

# Assuming df_to_obsolete and df_upheno_id_map are already defined
# Merge df_to_obsolete with df_upheno_id_map
df_upheno_id_map['upheno_id'] = df_upheno_id_map['defined_class'].str.replace('http://purl.obolibrary.org/obo/UPHENO_', 'UPHENO:')
df_robot_report_merged = df_robot_report.merge(df_upheno_id_map, how='left', left_on='Subject', right_on='upheno_id')
df_robot_report_merged['subject_id'] = df_robot_report_merged['id']
df_robot_report_merged.drop(columns=['id','defined_class','upheno_id'], inplace=True)
df_robot_report_merged
# Out:
#        Level             Rule Name         Subject     Property  \
# 0      ERROR  duplicate_definition  UPHENO:0079981  IAO:0000115
# 1      ERROR  duplicate_definition  UPHENO:0085427  IAO:0000115
# 2      ERROR  duplicate_definition  UPHENO:0079982  IAO:0000115
# 3      ERROR  duplicate_definition  UPHENO:0085425  IAO:0000115
# 4      ERROR  duplicate_definition  UPHENO:0079901  IAO:0000115
# ...      ...                   ...             ...          ...
# 10610   INFO  lowercase_definition  UPHENO:0090159  IAO:0000115
# 10611   INFO  lowercase_definition  UPHENO:0090160  IAO:0000115
# 10612   INFO  lowercase_definition  UPHENO:0090161  IAO:0000115
# 10613   INFO  lowercase_definition  UPHENO:0090162  IAO:0000115
# 10614   INFO  lowercase_definition  UPHENO:0090163  IAO:0000115
#
#                                                                          Value  \
# 0                 The presence of an increased number of vestibular hair cell.
# 1                 The presence of an increased number of vestibular hair cell.
# 2                   The presence of an increased number of type II pneumocyte.
# 3                   The presence of an increased number of type II pneumocyte.
# 4      The presence of an increased number of type II cell of adrenal medulla.
# ...                                                                        ...
# 10610                 longer, increased length of, photoreceptor outer segment
# 10611                             longer, increased length of, dendritic spine
# 10612                             longer, increased length of, sperm flagellum
# 10613                                   longer, increased length of, manchette
# 10614                                   longer, increased length of, germ tube
#
#                                                                                        subject_id
# 0      http://purl.obolibrary.org/obo/CL_0000609-abnormallyIncreasedNumberOfCellularComponent.tsv
# 1       http://purl.obolibrary.org/obo/CL_0000609-abnormallyIncreasedNumberOfAnatomicalEntity.tsv
# 2      http://purl.obolibrary.org/obo/CL_0002063-abnormallyIncreasedNumberOfCellularComponent.tsv
# 3       http://purl.obolibrary.org/obo/CL_0002063-abnormallyIncreasedNumberOfAnatomicalEntity.tsv
# 4      http://purl.obolibrary.org/obo/CL_0002082-abnormallyIncreasedNumberOfCellularComponent.tsv
# ...                                                                                           ...
# 10610   http://purl.obolibrary.org/obo/GO_0001750-abnormallyIncreasedLengthOfAnatomicalEntity.tsv
# 10611   http://purl.obolibrary.org/obo/GO_0043197-abnormallyIncreasedLengthOfAnatomicalEntity.tsv
# 10612   http://purl.obolibrary.org/obo/GO_0036126-abnormallyIncreasedLengthOfAnatomicalEntity.tsv
# 10613   http://purl.obolibrary.org/obo/GO_0002177-abnormallyIncreasedLengthOfAnatomicalEntity.tsv
# 10614   http://purl.obolibrary.org/obo/GO_0032179-abnormallyIncreasedLengthOfAnatomicalEntity.tsv
#
# [10615 rows x 6 columns]

# %%
import os
import pandas as pd

def handle_gocc_anatomical_entity(group, df_obsoletes, dir_patterns):
    upheno_id_cc = None
    upheno_id_ae = None
    pattern = None

    for index, row in group.iterrows():
        print(row)
        if "AnatomicalEntity" in row["subject_id"] and "GO_" in row["subject_id"]:
            if upheno_id_ae is None:
                upheno_id_ae = row["Subject"]
            else:
                print(f"AE already set.. {row['Subject']} {row['subject_id']} {row['Subject']}")
        elif "CellularComponent" in row["subject_id"] and "GO_" in row["subject_id"]:
            if upheno_id_cc is None:
                upheno_id_cc = row["Subject"]
            else:
                print(f"CC already set.. {row['Subject']} {row['subject_id']} {row['Subject']}")
        else:
            print(f"Unexpected subject_id {row['subject_id']} {row['Subject']}")

        if pattern is None and "AnatomicalEntity" in row["subject_id"]:
            pattern = row["subject_id"].split("-")[-1]

    if upheno_id_cc is not None and upheno_id_ae is not None and pattern is not None:
        new_obsolete_entry = pd.DataFrame([{
            "replacement": upheno_id_cc,
            "obsolete": upheno_id_ae,
            "comment": f"The {upheno_id_cc} was redundant with {upheno_id_ae}, just using a different pattern."
        }])
        
        df_obsoletes = pd.concat([df_obsoletes, new_obsolete_entry], ignore_index=True)


        pattern_file = os.path.join(dir_patterns, pattern)
        if os.path.exists(pattern_file):
            df_pattern = pd.read_csv(pattern_file)
            print(df_pattern.head())
            print(df_pattern.columns)
            if "defined_class" in df_pattern.columns:
                print(df_pattern["defined_class"])
                df_pattern = df_pattern[df_pattern["defined_class"] != upheno_id_ae]
                df_pattern.to_csv(pattern_file, index=False)
            else:
                print(df_pattern)

    return df_obsoletes

grouped_df = df_robot_report_merged[df_robot_report["Rule Name"] == "duplicate_definition"].groupby("Value")

all_cases = []
upheno_ids = [
    "UPHENO:0050409",
    "UPHENO:0002001",
    "UPHENO:0002002",
    "UPHENO:0002003",
    "UPHENO:0002004",
    "UPHENO:0050590",
    "UPHENO:0051262"
]

print(f"Group count{len(grouped_df)}")

i = 0
for definition, group in grouped_df:
    i = i + 1
    new_case = True
    replacements = []
    go_bp = False
    go_mf = False
    case_type = "unknown"
    for index, row in group.iterrows():
        if "MolecularFunction" in row["subject_id"]:
            go_mf = True
        if "BiologicalProcess" in row["subject_id"]:
            go_bp = True
        
        ### Fixing all cases
        if "AnatomicalEntity" in row["subject_id"] and "GO_" in row["subject_id"]:
            # Obsolete the term, replace with other (CC), discard from matches
            new_case = False
            case_type = "gocc_anatomical_entity"
            break
        elif "brokenAnatomicalEntity" in row["subject_id"] and "UBERON_" in row["subject_id"]:
            # Fixed by itself (changed pattern text)
            new_case = False
            case_type = "broken_fractured"
            break
        elif "LevelOfChemicalEntity" in row["subject_id"] and "PR_" in row["subject_id"]:
            # Just one fix manually
            new_case = False
            case_type = "pr_chemical_entity"
            break
        elif "CellularComponent" in row["subject_id"] and "CL_" in row["subject_id"]:
            # Big issue with CL being both CC and AE.
            # Fix:
            # 1. Drop CL from CC patterns entirely, and replace with CL-AE term
            # 2. Obsolete CL from CC terms
            # 3. Add check to matches to not include CL-CC cases
            new_case = False
            case_type = "cc_cl"
            break
        elif "abnormalFunctionalityOfPartOfAnatomicalEntity" in row["subject_id"]:
            # Fixed by itself (changed pattern text)
            new_case = False
            case_type = "functionality_partof"
            break
        elif "BiologicalProcess" in row["subject_id"] and "NBO_" in row["subject_id"]:
            # Smaller issue with NBO terms overlapping with BP.
            # Fix:
            # 1. Drop NBO from BP patterns entirely, and replace with BP term
            # 2. Obsolete NBO from BP terms
            # 3. Add check to matches to not include NBO-BP cases
            # 4. Output NBO-BP mappings to ensure NBO pattern matches are not excluded..
            new_case = False
            case_type = "nbo_bp"
            break
        elif "ResistanceOfWholeOrganismToEntity" in row["subject_id"] and "CHEBI_" in row["subject_id"]:
            # Biggest issue with CHEBI being both "entity" and "chemical entity".
            # Fix:
            # 1. Drop CHEBI from ResistanceOfWholeOrganismToEntity patterns entirely, and replace with CHEBI-ResistanceOfWholeOrganismToChemicalEntity term
            # 2. Obsolete CHEBI-ENTITY
            # 3. Add check to matches to not include CHEBI-ENTITY cases
            new_case = False
            case_type = "resistence_to_entity_chebi"
            break
        elif any(upheno_id in row["Subject"] for upheno_id in upheno_ids):
            # Already fixed
            new_case = False
            case_type = "fixed_id"
            break
        elif go_bp and go_mf:
            # All of these are molecular function. Delete the BP ones, add replacements
            new_case = False
            case_type = "bp_and_mf"
            break
        
    if new_case:
        print(f"Case {i}")
        print(group)
        break
    else:
        if case_type == "gocc_anatomical_entity":
            handle_gocc_anatomical_entity(group, df_obsoletes, automatic_data_dir)

# Create a DataFrame from the global list
#df_replacements = pd.DataFrame(all_cases)

#df_replacements.to_csv("replacements.tsv", sep="\t", index=False)
#df_replacements.value_counts("case_type")
df_obsoletes
# Out:
# Group count930
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0085672
# Property                                                                                   IAO:0000115
# Value                                           A reduction in the size of the alveolar lamellar body.
# subject_id    http://purl.obolibrary.org/obo/GO_0097208-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1850, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0089987
# Property                                                                                  IAO:0000115
# Value                                          A reduction in the size of the alveolar lamellar body.
# subject_id    http://purl.obolibrary.org/obo/GO_0097208-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1851, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083996
# Property                                                                                   IAO:0000115
# Value                                               A reduction in the size of the astral microtubule.
# subject_id    http://purl.obolibrary.org/obo/GO_0000235-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1848, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090007
# Property                                                                                  IAO:0000115
# Value                                              A reduction in the size of the astral microtubule.
# subject_id    http://purl.obolibrary.org/obo/GO_0000235-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1849, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0084000
# Property                                                                                   IAO:0000115
# Value                                              A reduction in the size of the contractile vacuole.
# subject_id    http://purl.obolibrary.org/obo/GO_0000331-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1846, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090005
# Property                                                                                  IAO:0000115
# Value                                             A reduction in the size of the contractile vacuole.
# subject_id    http://purl.obolibrary.org/obo/GO_0000331-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1847, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083998
# Property                                                                                   IAO:0000115
# Value                                                         A reduction in the size of the endosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0005768-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1844, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090006
# Property                                                                                  IAO:0000115
# Value                                                        A reduction in the size of the endosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0005768-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1845, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0082015
# Property                                                                                   IAO:0000115
# Value                                                    A reduction in the size of the lipid droplet.
# subject_id    http://purl.obolibrary.org/obo/GO_0005811-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1842, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090012
# Property                                                                                  IAO:0000115
# Value                                                   A reduction in the size of the lipid droplet.
# subject_id    http://purl.obolibrary.org/obo/GO_0005811-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1843, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083997
# Property                                                                                   IAO:0000115
# Value                                                         A reduction in the size of the lysosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0005764-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1840, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090008
# Property                                                                                  IAO:0000115
# Value                                                        A reduction in the size of the lysosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0005764-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1841, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0082012
# Property                                                                                   IAO:0000115
# Value                                                       A reduction in the size of the melanosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0042470-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1838, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0089998
# Property                                                                                  IAO:0000115
# Value                                                      A reduction in the size of the melanosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0042470-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1839, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0082011
# Property                                                                                   IAO:0000115
# Value                                                    A reduction in the size of the mitochondrion.
# subject_id    http://purl.obolibrary.org/obo/GO_0005739-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1836, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0089990
# Property                                                                                  IAO:0000115
# Value                                                   A reduction in the size of the mitochondrion.
# subject_id    http://purl.obolibrary.org/obo/GO_0005739-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1837, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0080058
# Property                                                                                  IAO:0000115
# Value                                                         A reduction in the size of the nucleus.
# subject_id    http://purl.obolibrary.org/obo/GO_0005634-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1834, dtype: object
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0082014
# Property                                                                                   IAO:0000115
# Value                                                          A reduction in the size of the nucleus.
# subject_id    http://purl.obolibrary.org/obo/GO_0005634-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1835, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083992
# Property                                                                                   IAO:0000115
# Value                                                    A reduction in the size of the phagolysosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0032010-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1832, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090010
# Property                                                                                  IAO:0000115
# Value                                                   A reduction in the size of the phagolysosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0032010-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1833, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083993
# Property                                                                                   IAO:0000115
# Value                                                         A reduction in the size of the pinosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0044352-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1830, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090011
# Property                                                                                  IAO:0000115
# Value                                                        A reduction in the size of the pinosome.
# subject_id    http://purl.obolibrary.org/obo/GO_0044352-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1831, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083999
# Property                                                                                   IAO:0000115
# Value                                           A reduction in the size of the post-lysosomal vacuole.
# subject_id    http://purl.obolibrary.org/obo/GO_0032195-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1828, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090004
# Property                                                                                  IAO:0000115
# Value                                          A reduction in the size of the post-lysosomal vacuole.
# subject_id    http://purl.obolibrary.org/obo/GO_0032195-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1829, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0083994
# Property                                                                                   IAO:0000115
# Value                                                     A reduction in the size of the pseudopodium.
# subject_id    http://purl.obolibrary.org/obo/GO_0031143-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1826, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090009
# Property                                                                                  IAO:0000115
# Value                                                    A reduction in the size of the pseudopodium.
# subject_id    http://purl.obolibrary.org/obo/GO_0031143-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1827, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0084413
# Property                                                                                   IAO:0000115
# Value                                                       A reduction in the size of the sperm head.
# subject_id    http://purl.obolibrary.org/obo/GO_0061827-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1824, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0089988
# Property                                                                                  IAO:0000115
# Value                                                      A reduction in the size of the sperm head.
# subject_id    http://purl.obolibrary.org/obo/GO_0061827-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1825, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0088542
# Property                                                                                   IAO:0000115
# Value                                       A reduction in the size of the sperm mitochondrial sheath.
# subject_id    http://purl.obolibrary.org/obo/GO_0097226-abnormallyDecreasedSizeOfCellularComponent.tsv
# Name: 1822, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0090003
# Property                                                                                  IAO:0000115
# Value                                      A reduction in the size of the sperm mitochondrial sheath.
# subject_id    http://purl.obolibrary.org/obo/GO_0097226-abnormallyDecreasedSizeOfAnatomicalEntity.tsv
# Name: 1823, dtype: object
#                                anatomical_entity  \
# 0  http://purl.obolibrary.org/obo/UBERON_0004187
# 1  http://purl.obolibrary.org/obo/UBERON_0004066
# 2  http://purl.obolibrary.org/obo/UBERON_0008780
# 3  http://purl.obolibrary.org/obo/UBERON_0000388
# 4  http://purl.obolibrary.org/obo/UBERON_0003655
#
#                                    defined_class
# 0  http://purl.obolibrary.org/obo/UPHENO_0068825
# 1  http://purl.obolibrary.org/obo/UPHENO_0068828
# 2  http://purl.obolibrary.org/obo/UPHENO_0068829
# 3  http://purl.obolibrary.org/obo/UPHENO_0069159
# 4  http://purl.obolibrary.org/obo/UPHENO_0069160
# Index(['anatomical_entity', 'defined_class'], dtype='object')
#                                   anatomical_entity  \
# 0     http://purl.obolibrary.org/obo/UBERON_0004187
# 1     http://purl.obolibrary.org/obo/UBERON_0004066
# 2     http://purl.obolibrary.org/obo/UBERON_0008780
# 3     http://purl.obolibrary.org/obo/UBERON_0000388
# 4     http://purl.obolibrary.org/obo/UBERON_0003655
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UBERON_0001707
# 1295  http://purl.obolibrary.org/obo/UBERON_0001948
# 1296  http://purl.obolibrary.org/obo/UBERON_0001928
# 1297  http://purl.obolibrary.org/obo/UBERON_0005283
# 1298  http://purl.obolibrary.org/obo/UBERON_0005281
#
#                                       defined_class
# 0     http://purl.obolibrary.org/obo/UPHENO_0068825
# 1     http://purl.obolibrary.org/obo/UPHENO_0068828
# 2     http://purl.obolibrary.org/obo/UPHENO_0068829
# 3     http://purl.obolibrary.org/obo/UPHENO_0069159
# 4     http://purl.obolibrary.org/obo/UPHENO_0069160
# ...                                             ...
# 1294  http://purl.obolibrary.org/obo/UPHENO_0070483
# 1295  http://purl.obolibrary.org/obo/UPHENO_0070484
# 1296  http://purl.obolibrary.org/obo/UPHENO_0070509
# 1297  http://purl.obolibrary.org/obo/UPHENO_0070515
# 1298  http://purl.obolibrary.org/obo/UPHENO_0070516
#
# [1299 rows x 2 columns]
# Level                                                                                            ERROR
# Rule Name                                                                         duplicate_definition
# Subject                                                                                 UPHENO:0086350
# Property                                                                                   IAO:0000115
# Value                                           An increase in the size of the alveolar lamellar body.
# subject_id    http://purl.obolibrary.org/obo/GO_0097208-abnormallyIncreasedSizeOfCellularComponent.tsv
# Name: 1818, dtype: object
# Level                                                                                           ERROR
# Rule Name                                                                        duplicate_definition
# Subject                                                                                UPHENO:0088450
# Property                                                                                  IAO:0000115
# Value                                          An increase in the size of the alveolar lamellar body.
# subject_id    http://purl.obolibrary.org/obo/GO_0097208-abnormallyIncreasedSizeOfAnatomicalEntity.tsv
# Name: 1819, dtype: object
#                                                                anatomical_entity\tdefined_class
# 0  http://purl.obolibrary.org/obo/UBERON_0004187\thttp://purl.obolibrary.org/obo/UPHENO_0000950
# 1  http://purl.obolibrary.org/obo/UBERON_0001471\thttp://purl.obolibrary.org/obo/UPHENO_0001212
# 2  http://purl.obolibrary.org/obo/UBERON_0000388\thttp://purl.obolibrary.org/obo/UPHENO_0001214
# 3  http://purl.obolibrary.org/obo/UBERON_0001236\thttp://purl.obolibrary.org/obo/UPHENO_0001215
# 4  http://purl.obolibrary.org/obo/UBERON_0001473\thttp://purl.obolibrary.org/obo/UPHENO_0001216
# Index(['anatomical_entity\tdefined_class'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'defined_class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 146
#     144     else:
#     145         if case_type == "gocc_anatomical_entity":
# --> 146             handle_gocc_anatomical_entity(group, df_obsoletes, automatic_data_dir)
#     148 # Create a DataFrame from the global list
#     149 #df_replacements = pd.DataFrame(all_cases)
#     150
#     151 #df_replacements.to_csv("replacements.tsv", sep="\t", index=False)
#     152 #df_replacements.value_counts("case_type")
#     153 df_obsoletes
#
# Cell In[88], line 43, in handle_gocc_anatomical_entity(group, df_obsoletes, dir_patterns)
#      41 print(df_pattern.columns)
#      42 if "defined_class" not in df_pattern.columns:
# ---> 43     print(df_pattern["defined_class"])
#      44     df_pattern = df_pattern[df_pattern["defined_class"] != upheno_id_ae]
#      45     df_pattern.to_csv(pattern_file, index=False)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'defined_class'

# %%
import pandas as pd

# Assuming df_to_obsolete and df_upheno_id_map are already defined
# Merge df_to_obsolete with df_upheno_id_map
df_upheno_id_map['upheno_id'] = df_upheno_id_map['defined_class'].str.replace('http://purl.obolibrary.org/obo/UPHENO_', 'UPHENO:')
merged_df = df_to_obsolete.merge(df_upheno_id_map, how='left', left_on='obsolete', right_on='upheno_id')
merged_df['obsolete_id'] = merged_df['id']
merged_df.drop(columns=['id','defined_class','upheno_id'], inplace=True)
merged_df = merged_df.merge(df_upheno_id_map, how='left', left_on='replacement', right_on='upheno_id')
merged_df['replacement_id'] = merged_df['id']
merged_df.drop(columns=['id','defined_class','upheno_id'], inplace=True)

# Display the merged DataFrame
merged_df.to_csv("to_obsolete_with_replacements.tsv", sep="\t", index=False)
merged_df
# Out:
#            obsolete     replacement  \
# 0    UPHENO:0080366  UPHENO:0051215
# 1    UPHENO:0081401  UPHENO:0080438
# 2    UPHENO:0081408  UPHENO:0080477
# 3    UPHENO:0081409  UPHENO:0080515
# 4    UPHENO:0081403  UPHENO:0080524
# ..              ...             ...
# 926  UPHENO:0005594  UPHENO:0005443
# 927  UPHENO:0086161  UPHENO:0080266
# 928  UPHENO:0005678  UPHENO:0005500
# 929  UPHENO:0005493  UPHENO:0005409
# 930  UPHENO:0076900  UPHENO:0005766
#
#                                                                                    obsolete_id  \
# 0                      http://purl.obolibrary.org/obo/GO_0005215-abnormalMolecularFunction.tsv
# 1                     http://purl.obolibrary.org/obo/UBERON_0001062-brokenAnatomicalEntity.tsv
# 2                     http://purl.obolibrary.org/obo/UBERON_0004395-brokenAnatomicalEntity.tsv
# 3                     http://purl.obolibrary.org/obo/UBERON_0000976-brokenAnatomicalEntity.tsv
# 4                     http://purl.obolibrary.org/obo/UBERON_0002228-brokenAnatomicalEntity.tsv
# ..                                                                                         ...
# 926  http://purl.obolibrary.org/obo/NBO_0000084-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 927   http://purl.obolibrary.org/obo/GO_0007625-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 928   http://purl.obolibrary.org/obo/GO_0007626-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 929  http://purl.obolibrary.org/obo/NBO_0000008-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 930  http://purl.obolibrary.org/obo/NBO_0000381-abnormallyDecreasedRateOfBiologicalProcess.tsv
#
#                                                                                 replacement_id
# 0                      http://purl.obolibrary.org/obo/GO_0005215-abnormalBiologicalProcess.tsv
# 1                  http://purl.obolibrary.org/obo/UBERON_0001062-fracturedAnatomicalEntity.tsv
# 2                  http://purl.obolibrary.org/obo/UBERON_0004395-fracturedAnatomicalEntity.tsv
# 3                  http://purl.obolibrary.org/obo/UBERON_0000976-fracturedAnatomicalEntity.tsv
# 4                  http://purl.obolibrary.org/obo/UBERON_0002228-fracturedAnatomicalEntity.tsv
# ..                                                                                         ...
# 926   http://purl.obolibrary.org/obo/GO_0048512-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 927  http://purl.obolibrary.org/obo/NBO_0000027-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 928  http://purl.obolibrary.org/obo/NBO_0000013-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 929   http://purl.obolibrary.org/obo/GO_0007622-abnormallyDecreasedRateOfBiologicalProcess.tsv
# 930   http://purl.obolibrary.org/obo/GO_0001966-abnormallyDecreasedRateOfBiologicalProcess.tsv
#
# [931 rows x 4 columns]
